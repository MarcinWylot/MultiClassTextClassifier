# %%
# !wget https://www.dropbox.com/s/6mfe1c4tjqjn8d4/preprocessed_data.pkl?dl=1
# !mv preprocessed_data.pkl?dl=1 preprocessed_data.pkl
# !ls -lh
# Out:
# Redirecting output to ‘wget-log’.
# total 365M
# -rw-r--r-- 1 root root 365M Sep 11 14:27 preprocessed_data.pkl
# drwxr-xr-x 2 root root 4.0K Sep  7 20:49 sample_data
# -rw-r--r-- 1 root root 5.0K Sep 11 14:27 wget-log

# %%
from sklearn.feature_selection import chi2
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
df = pd.read_pickle("./preprocessed_data.pkl")

tfidf = TfidfVectorizer(sublinear_tf=True, min_df = 20, ngram_range=(1, 2), stop_words='english')

description = tfidf.fit_transform(df['description']).toarray()

N=2
for industry in sorted(df['industry'].unique()):
    description_chi2 = chi2(description, df['industry'] == industry)
    indices = np.argsort(description_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("# '{}':".format(industry))
    print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:])))
    print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:])))
# Out:
# # 'Accounting':
#   . Most correlated unigrams:
#        . tax
#        . accounting
#   . Most correlated bigrams:
#        . accounting firm
#        . accounting company
# # 'Apparel & Fashion':
#   . Most correlated unigrams:
#        . apparel
#        . fashion
#   . Most correlated bigrams:
#        . apparel fashion
#        . fashion company
# # 'Architecture & Planning':
#   . Most correlated unigrams:
#        . architects
#        . architecture
#   . Most correlated bigrams:
#        . planning company
#        . architecture planning
# # 'Automotive':
#   . Most correlated unigrams:
#        . auto
#        . automotive
#   . Most correlated bigrams:
#        . new used
#        . automotive company
# # 'Biotechnology':
#   . Most correlated unigrams:
#        . biological
#        . biotechnology
#   . Most correlated bigrams:
#        . life science
#        . biotechnology company
# # 'Broadcast Media':
#   . Most correlated unigrams:
#        . broadcast
# ...

# %%
from sklearn.feature_selection import chi2
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
df = pd.read_pickle("./preprocessed_data.pkl")

tfidf = TfidfVectorizer(sublinear_tf=True, min_df = 20, ngram_range=(1, 2), stop_words='english', max_features = 1000)

description = tfidf.fit_transform(df['html2text']).toarray()

N=2
for industry in sorted(df['industry'].unique()):
    description_chi2 = chi2(description, df['industry'] == industry)
    indices = np.argsort(description_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("# '{}':".format(industry))
    print("  . Most correlated unigrams:\n       . {}".format('\n       . '.join(unigrams[-N:])))
    print("  . Most correlated bigrams:\n       . {}".format('\n       . '.join(bigrams[-N:])))
# Out:
# # 'Accounting':
#   . Most correlated unigrams:
#        . financial
#        . tax
#   . Most correlated bigrams:
#        . px height
#        . nav ul
# # 'Apparel & Fashion':
#   . Most correlated unigrams:
#        . shop
#        . cart
#   . Most correlated bigrams:
#        . real estate
#        . div div
# # 'Architecture & Planning':
#   . Most correlated unigrams:
#        . projects
#        . design
#   . Most correlated bigrams:
#        . wsiteformfield label
#        . social media
# # 'Automotive':
#   . Most correlated unigrams:
#        . car
#        . vehicle
#   . Most correlated bigrams:
#        . center norepeat
#        . div div
# # 'Biotechnology':
#   . Most correlated unigrams:
#        . medical
#        . research
#   . Most correlated bigrams:
#        . menu ul
#        . real estate
# # 'Broadcast Media':
#   . Most correlated unigrams:
#        . production
#        . live
#   . Most correlated bigrams:
#        . width height
# ...
